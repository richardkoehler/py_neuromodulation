# %% [markdown]
# # Details of an Example Use Case
#
# The example_BIDS.py file is a Python script that illustrates how the user would use the py_neuromodulation software. In this notebook, we take this example and go over it step by step, in order to give a better intuition behind each step.
#
# We took subject-000 from this dataset: https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/IO2FLM, and cropped it such that we would capture 4 movement traces.
#
# In standard `py_neuromodulation` usage, we start with importing the necessary packages:

# %%
import os
import sys

# change root directory of the project
SCRIPT_DIR = os.path.dirname(os.path.abspath(''))
if os.path.basename(SCRIPT_DIR) == "py_neuromodulation":
    # this check is necessary, so we can also run the script from the root directory
    SCRIPT_DIR = os.path.join(SCRIPT_DIR, "examples")

sys.path.append(os.path.dirname(SCRIPT_DIR))

# Reload imports to get changes in other scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import py_neuromodulation as nm
import xgboost
from py_neuromodulation import (
    nm_analysis,
    nm_decode,
    nm_define_nmchannels,
    nm_IO,
    nm_plots,
    nm_stats
)
from sklearn import metrics, model_selection
import json
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Read BIDS data
#
# The first step in any use case is loading the data. Here, we show how the user would load data that is stored in the BIDS format, using the function `nm_IO.read_BIDS_data()`.
#
# py_neuromodulation can perform feature estimation and decoding in other types of data, but the user is responsible for the loading step and for guaranteeing that all necessary information is provided. In the next steps we point out which information all datasets must contain in order to use the pipeline.
#
# The function `nm_IO.read_BIDS_data()` can take as parameter the `line_noise`, which refers to the power line noise. In europe that has the value of 50 Hz, set as default, and in the US this value is 60 Hz. Since here we'll be using a dataset collected in the US, we set the line noise to 60Hz. Generally, this value can also be found in the data.

# %% [markdown]
# # Only works if we add the participant to participants.tsv file!
# # THey have their own participants.tsv file, should I insert that on github or just add sub-000 to ours?
#
# #Which task were they performing? In paper there's grip force decoding, but also there are LFP electrodes, which we dont have here.

# %%
sub = "000"
ses = "right"
task = "force"
run = 0
datatype = "ieeg"

# Define run name and access paths in the BIDS format.
RUN_NAME = f"sub-{sub}_ses-{ses}_task-{task}_run-{run}"

PATH_RUN = os.path.join(
    (os.path.join(SCRIPT_DIR, "data")),
    f"sub-{sub}",
    f"ses-{ses}",
    datatype,
    RUN_NAME,
)
PATH_BIDS = os.path.join(SCRIPT_DIR, "data")

# Provide a path for the output data.
PATH_OUT = os.path.join(SCRIPT_DIR, "data", "derivatives")

(
    raw,
    data,
    sfreq,
    line_noise,
    coord_list,
    coord_names,
) = nm_IO.read_BIDS_data(
    PATH_RUN=PATH_RUN, BIDS_PATH=PATH_BIDS, datatype=datatype, line_noise=60
)
# Out:
# Extracting parameters from /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/sub-000/ses-right/ieeg/sub-000_ses-right_task-force_run-0_ieeg.vhdr...
# Setting channel info structure...
# Reading channel info from /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/sub-000/ses-right/ieeg/sub-000_ses-right_task-force_run-0_channels.tsv.
# Reading electrode coords from /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/sub-000/ses-right/ieeg/sub-000_ses-right_task-force_run-0_space-mni_electrodes.tsv.
# Line noise is not available in the data, using value of 60 Hz.

# %% [markdown]
# ##  Define the channels
#
# BIDS data is saved in BrainVision format, which consists of three separate files:
#
# - A text header file (.vhdr) containing meta data
# - A text marker file (.vmrk) containing information about events in the data
# - A binary data file (.eeg) containing the voltage values of the EEG (or as in our case, iEEG)
#
# The MNE-BIDS Python library reads this data and stores it in a MNE-Python Raw object.
#
# This Raw object has as attribute the channel names, and as a method get_channel_types, that returns a list of channel type for each channel.
#
# The Raw object also stores the measurement information in raw.info, where one can also access the bad channels, i.e, a list of noisy/broken channels, by name. These channels will by default be ignored by many processing steps.
#
# __If the user insert by hand the list of channel names, their respective types and the information on which are the bad ones, any type of data can be used, not necessarily in the BIDS format.__
#
# Here "MOV_LEFT_CLEAN" is used as target channel. After feature estimation, this channel will be normalized and added in a time aligned manner to the features output csv file.aa

# %%
nm_channels = nm_define_nmchannels.set_channels(
    ch_names=raw.ch_names,
    ch_types=raw.get_channel_types(),
    reference="default",
    bads=raw.info["bads"],
    new_names="default",
    used_types=("ecog"),
    ecog_only=True,
    target_keywords=("MOV_LEFT_CLEAN"),
)

# %% [markdown]
# ```nm_channels``` is a pandas dataframe that stores all information about the channels: their names, before and after rereferencing, which type of rereferencing was done, whether they were used or not, if they were marked as targets, and if they were market as bad or bad channels.

# %%
nm_channels
# Out:
#               name rereference  used  target  type status             new_name
# 0     ECOG_RIGHT_0     average     1       0  ecog   good  ECOG_RIGHT_0-avgref
# 1     ECOG_RIGHT_1     average     1       0  ecog   good  ECOG_RIGHT_1-avgref
# 2     ECOG_RIGHT_2     average     1       0  ecog   good  ECOG_RIGHT_2-avgref
# 3     ECOG_RIGHT_3     average     1       0  ecog   good  ECOG_RIGHT_3-avgref
# 4     ECOG_RIGHT_4     average     1       0  ecog   good  ECOG_RIGHT_4-avgref
# 5     ECOG_RIGHT_5     average     1       0  ecog   good  ECOG_RIGHT_5-avgref
# 6        MOV_RIGHT        None     0       0  misc   good            MOV_RIGHT
# 7         MOV_LEFT        None     0       0  misc   good             MOV_LEFT
# 8  MOV_RIGHT_CLEAN        None     0       0  misc   good      MOV_RIGHT_CLEAN
# 9   MOV_LEFT_CLEAN        None     0       1  misc   good       MOV_LEFT_CLEAN

# %% [markdown]
# ## Feature Estimation
#
# nm.Stream is where the magic happens. It is the class that handles all feature estimation steps. First we create an instance of that class, and then use the set_settings_fast_compute function to only select fft features and a minimal set of rereferencing, normalization, notch filtering and post processing normalization methods. Afterwards, we manually set some other features that we want to compute as `True`.

# %%
stream = nm.Stream(
    settings=None,
    nm_channels=nm_channels,
    path_grids=None,
    verbose=True,
)

stream.set_settings_fast_compute()
stream.settings["features"]["raw_hjorth"] = True
stream.settings["features"]["bandpass_filter"] = True
stream.settings["features"]["fft"] = True
stream.settings["features"]["sharpwave_analysis"] = True
stream.settings["features"]["fooof"] = True
stream.settings["features"]["nolds"] = False
stream.settings["features"]["bursts"] = True


# Additional sharpwave features
stream.settings["sharpwave_analysis_settings"]["sharpwave_features"][
        "width"
    ] = True
stream.settings["sharpwave_analysis_settings"]["sharpwave_features"][
    "decay_time"
] = True
stream.settings["sharpwave_analysis_settings"]["sharpwave_features"][
    "rise_time"
] = True
stream.settings["sharpwave_analysis_settings"]["sharpwave_features"][
    "rise_steepness"
] = True
stream.settings["sharpwave_analysis_settings"]["sharpwave_features"][
    "decay_steepness"
] = True

stream.settings["sharpwave_analysis_settings"]["sharpwave_features"][
    "slope_ratio"
] = True


stream.settings["sharpwave_analysis_settings"]["estimator"]["mean"] = [
    "width",
    "decay_time",
    "rise_time",
    "rise_steepness",
    "decay_steepness",
    "sharpness",
    "prominence",
    "interval",
    "slope_ratio",
]

stream.settings["sharpwave_analysis_settings"]["estimator"]["var"] = [
    "width",
    "decay_time",
    "rise_time",
    "rise_steepness",
    "decay_steepness",
    "sharpness",
    "prominence",
    "interval",
    "slope_ratio",
]

stream.settings["sharpwave_analysis_settings"]["estimator"]["max"] = [
    "sharpness",
    "prominence",
]


# for now we only look at the aperiodic component of fooof
stream.settings["fooof"]["periodic"]["center_frequency"] = False
stream.settings["fooof"]["periodic"]["band_width"] = False
stream.settings["fooof"]["periodic"]["height_over_ap"] = False

# If we also want to compute nolds features (‘NOnLinear measures for Dynamical Systems’), this is how to select the frequency bands:

stream.settings["nolds_features"]["data"]["frequency_bands"] = [
                "theta",
                "alpha",
                "low beta",
                "high gamma"]

stream.settings["postprocessing"]["feature_normalization"] = False
stream.settings["postprocessing"]["project_cortex"] = True
stream.settings["postprocessing"]["project_subcortex"] = False

# %% [markdown]
# All settings that the user can alter are defined within `py_neuromodulation/nm_settings.json`. The user can either alter that file to select their preffered settings, or access it through the dictionary in `stream.settings`.
# In the cell below we print the settings selected that are going to be used in our analysis.

# %% [markdown]
# # Need project subcortex to be false. Should we assume user will do that?

# %%
print(json.dumps(stream.settings, indent=2))
# Out:
# {
#   "sampling_rate_features_hz": 10,
#   "segment_length_features_ms": 1000,
#   "preprocessing": {
#     "raw_resampling": true,
#     "raw_normalization": false,
#     "re_referencing": true,
#     "notch_filter": true,
#     "preprocessing_order": [
#       "raw_resampling",
#       "notch_filter",
#       "re_referencing"
#     ]
#   },
#   "features": {
#     "raw_hjorth": true,
#     "return_raw": false,
#     "bandpass_filter": true,
#     "stft": false,
#     "fft": true,
#     "sharpwave_analysis": true,
#     "coherence": false,
#     "fooof": true,
#     "nolds": false,
#     "bursts": true,
#     "linelength": false,
#     "mne_connectiviy": false
#   },
#   "postprocessing": {
#     "feature_normalization": false,
#     "project_cortex": true,
#     "project_subcortex": false
#   },
#   "raw_resampling_settings": {
#     "resample_freq_hz": 1000
#   },
#   "raw_normalization_settings": {
#     "normalization_time_s": 30,
#     "normalization_method": "zscore",
#     "clip": 3
#   },
#   "feature_normalization_settings": {
#     "normalization_time_s": 30,
#     "normalization_method": "zscore",
#     "clip": 3
#   },
#   "frequency_ranges_hz": {
#     "theta": [
#       4,
#       8
#     ],
#     "alpha": [
#       8,
#       12
#     ],
#     "low beta": [
#       13,
#       20
#     ],
#     "high beta": [
#       20,
#       35
#     ],
#     "low gamma": [
#       60,
#       80
#     ],
#     "high gamma": [
#       90,
#       200
#     ],
#     "HFA": [
#       200,
#       400
#     ]
#   },
#   "bandpass_filter_settings": {
#     "segment_lengths_ms": {
#       "theta": 1000,
#       "alpha": 500,
#       "low beta": 333,
#       "high beta": 333,
#       "low gamma": 100,
#       "high gamma": 100,
#       "HFA": 100
#     },
#     "bandpower_features": {
#       "activity": true,
#       "mobility": false,
#       "complexity": false
#     },
#     "log_transform": true,
#     "kalman_filter": true
#   },
#   "kalman_filter_settings": {
#     "Tp": 0.1,
#     "sigma_w": 0.7,
#     "sigma_v": 1,
#     "frequency_bands": [
#       "theta",
#       "alpha",
#       "low beta",
#       "high beta",
#       "low gamma",
#       "high gamma",
#       "HFA"
#     ]
#   },
#   "burst_settings": {
#     "threshold": 75,
#     "time_duration_s": 30,
#     "frequency_bands": [
#       "low beta",
#       "high beta",
#       "low gamma"
#     ],
#     "burst_features": {
#       "duration": true,
#       "amplitude": true,
#       "burst_rate_per_s": true,
#       "in_burst": true
#     }
#   },
#   "stft_settings": {
#     "windowlength_ms": 500,
#     "log_transform": true,
#     "kalman_filter": true
#   },
#   "fft_settings": {
#     "windowlength_ms": 1000,
#     "log_transform": true,
#     "kalman_filter": true
#   },
#   "sharpwave_analysis_settings": {
#     "sharpwave_features": {
#       "peak_left": false,
#       "peak_right": false,
#       "trough": false,
#       "width": true,
#       "prominence": true,
#       "interval": true,
#       "decay_time": true,
#       "rise_time": true,
#       "sharpness": true,
#       "rise_steepness": true,
#       "decay_steepness": true,
#       "slope_ratio": true
#     },
#     "filter_ranges_hz": [
#       [
#         5,
#         80
#       ],
#       [
#         5,
#         30
#       ]
#     ],
#     "detect_troughs": {
#       "estimate": true,
#       "distance_troughs_ms": 10,
#       "distance_peaks_ms": 5
#     },
#     "detect_peaks": {
#       "estimate": true,
#       "distance_troughs_ms": 5,
#       "distance_peaks_ms": 10
#     },
#     "estimator": {
#       "mean": [
#         "width",
#         "decay_time",
#         "rise_time",
#         "rise_steepness",
#         "decay_steepness",
#         "sharpness",
#         "prominence",
#         "interval",
#         "slope_ratio"
#       ],
#       "median": null,
#       "max": [
#         "sharpness",
#         "prominence"
#       ],
#       "min": null,
#       "var": [
#         "width",
#         "decay_time",
#         "rise_time",
#         "rise_steepness",
#         "decay_steepness",
#         "sharpness",
#         "prominence",
#         "interval",
#         "slope_ratio"
#       ]
#     },
#     "apply_estimator_between_peaks_and_troughs": true
#   },
#   "project_cortex_settings": {
#     "max_dist_mm": 20
#   },
#   "project_subcortex_settings": {
#     "max_dist_mm": 5
#   },
#   "coherence": {
#     "channels": [
#       [
#         "LFP_L_1_STN_BS",
#         "ECOG_L_4_SMC_AT"
#       ]
#     ],
#     "frequency_bands": [
#       "high beta"
#     ],
#     "features": {
#       "mean_fband": true,
#       "max_fband": true,
#       "max_allfbands": true
#     },
#     "method": {
#       "coh": true,
#       "icoh": true
#     },
#     "params": {
#       "window": "hann"
#     }
#   },
#   "fooof": {
#     "aperiodic": {
#       "exponent": true,
#       "offset": true
#     },
#     "periodic": {
#       "center_frequency": false,
#       "band_width": false,
#       "height_over_ap": false
#     },
#     "windowlength_ms": 800,
#     "peak_width_limits": [
#       0.5,
#       12
#     ],
#     "max_n_peaks": 3,
#     "min_peak_height": 0,
#     "peak_threshold": 2,
#     "freq_range_hz": [
#       2,
#       40
#     ],
#     "knee": true
#   },
#   "nolds_features": {
#     "sample_entropy": true,
#     "correlation_dimension": true,
#     "lyapunov_exponent": true,
#     "hurst_exponent": true,
#     "detrended_fluctutaion_analysis": true,
#     "data": {
#       "raw": true,
#       "frequency_bands": [
#         "theta",
#         "alpha",
#         "low beta",
#         "high gamma"
#       ]
#     }
#   },
#   "mne_connectiviy": {
#     "method": "plv",
#     "mode": "multitaper"
#   }
# }

# %% [markdown]
# __ATTENTION__: estimation of nolds features makes computation time much longer. If the user does not want to estimate them
# `stream.settings["features"]["nolds"]` needs to be set to `False`.
#
# __Without nolds features, 100ms of data takes between 0.1 and 0.2 seconds to be processed.__

# %% [markdown]
# In the cell below, if the user provides sfreq, line_noise, coord_list and coord_names, then there's no need for data in BIDS format.
#
# In stream.run the data should also be manually inserted.

# %%
stream.init_stream(
    sfreq=sfreq,
    line_noise=line_noise,
    coord_list=coord_list,
    coord_names=coord_names,
)

stream.run(
    data=data,
    out_path_root=PATH_OUT,
    folder_name=RUN_NAME,
)
# Out:
# No Error occurred when testing the settings.
# No data specified. Sanity checks related to the length of the signal relative to the filter order will be skipped.
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 7.50 Hz
# - Upper transition bandwidth: 7.50 Hz
# - Filter length: 999 samples (0.999 sec)
#
# Last batch took: 0.22 seconds
# 1.0 seconds of data processed
# Last batch took: 0.32 seconds
# 1.1 seconds of data processed
# Last batch took: 0.23 seconds
# 1.2 seconds of data processed
# Last batch took: 0.24 seconds
# 1.3 seconds of data processed
# Last batch took: 0.27 seconds
# 1.4 seconds of data processed
# Last batch took: 0.25 seconds
# 1.5 seconds of data processed
# Last batch took: 0.26 seconds
# 1.6 seconds of data processed
# Last batch took: 0.22 seconds
# 1.7 seconds of data processed
# Last batch took: 0.2 seconds
# 1.8 seconds of data processed
# Last batch took: 0.38 seconds
# 1.9 seconds of data processed
# Last batch took: 0.28 seconds
# 2.0 seconds of data processed
# Last batch took: 0.26 seconds
# 2.1 seconds of data processed
# Last batch took: 0.38 seconds
# 2.2 seconds of data processed
# Last batch took: 0.22 seconds
# 2.3 seconds of data processed
# Last batch took: 0.29 seconds
# 2.4 seconds of data processed
# Last batch took: 0.22 seconds
# 2.5 seconds of data processed
# Last batch took: 0.18 seconds
# 2.6 seconds of data processed
# Last batch took: 0.29 seconds
# 2.7 seconds of data processed
# Last batch took: 0.22 seconds
# 2.8 seconds of data processed
# Last batch took: 0.24 seconds
# 2.9 seconds of data processed
# Last batch took: 0.18 seconds
# 3.0 seconds of data processed
# Last batch took: 0.32 seconds
# 3.1 seconds of data processed
# Last batch took: 0.31 seconds
# 3.2 seconds of data processed
# Last batch took: 0.2 seconds
# 3.3 seconds of data processed
# Last batch took: 0.2 seconds
# 3.4 seconds of data processed
# Last batch took: 0.24 seconds
# 3.5 seconds of data processed
# Last batch took: 0.23 seconds
# 3.6 seconds of data processed
# Last batch took: 0.25 seconds
# 3.7 seconds of data processed
# Last batch took: 0.24 seconds
# 3.8 seconds of data processed
# Last batch took: 0.28 seconds
# 3.9 seconds of data processed
# Last batch took: 0.27 seconds
# 4.0 seconds of data processed
# Last batch took: 0.2 seconds
# 4.1 seconds of data processed
# Last batch took: 0.32 seconds
# 4.2 seconds of data processed
# Last batch took: 0.33 seconds
# 4.3 seconds of data processed
# Last batch took: 0.33 seconds
# 4.4 seconds of data processed
# Last batch took: 0.48 seconds
# 4.5 seconds of data processed
# Last batch took: 0.54 seconds
# 4.6 seconds of data processed
# Last batch took: 0.29 seconds
# 4.7 seconds of data processed
# Last batch took: 0.47 seconds
# 4.8 seconds of data processed
# Last batch took: 0.38 seconds
# 4.9 seconds of data processed
# Last batch took: 0.36 seconds
# 5.0 seconds of data processed
# Last batch took: 0.25 seconds
# 5.1 seconds of data processed
# Last batch took: 0.32 seconds
# 5.2 seconds of data processed
# Last batch took: 0.21 seconds
# 5.3 seconds of data processed
# Last batch took: 0.29 seconds
# 5.4 seconds of data processed
# Last batch took: 0.23 seconds
# 5.5 seconds of data processed
# Last batch took: 0.24 seconds
# 5.6 seconds of data processed
# Last batch took: 0.24 seconds
# 5.7 seconds of data processed
# Last batch took: 0.26 seconds
# 5.8 seconds of data processed
# Last batch took: 0.24 seconds
# 5.9 seconds of data processed
# Last batch took: 0.26 seconds
# 6.0 seconds of data processed
# Last batch took: 0.17 seconds
# 6.1 seconds of data processed
# Last batch took: 0.2 seconds
# 6.2 seconds of data processed
# Last batch took: 0.27 seconds
# 6.3 seconds of data processed
# Last batch took: 0.35 seconds
# 6.4 seconds of data processed
# Last batch took: 0.22 seconds
# 6.5 seconds of data processed
# Last batch took: 0.22 seconds
# 6.6 seconds of data processed
# Last batch took: 0.2 seconds
# 6.7 seconds of data processed
# Last batch took: 0.33 seconds
# 6.8 seconds of data processed
# Last batch took: 0.25 seconds
# 6.9 seconds of data processed
# Last batch took: 0.23 seconds
# 7.0 seconds of data processed
# Last batch took: 0.28 seconds
# 7.1 seconds of data processed
# Last batch took: 0.22 seconds
# 7.2 seconds of data processed
# Last batch took: 0.3 seconds
# 7.3 seconds of data processed
# Last batch took: 0.25 seconds
# 7.4 seconds of data processed
# Last batch took: 0.23 seconds
# 7.5 seconds of data processed
# Last batch took: 0.25 seconds
# 7.6 seconds of data processed
# Last batch took: 0.29 seconds
# 7.7 seconds of data processed
# Last batch took: 0.22 seconds
# 7.8 seconds of data processed
# Last batch took: 0.23 seconds
# 7.9 seconds of data processed
# Last batch took: 0.21 seconds
# 8.0 seconds of data processed
# Last batch took: 0.17 seconds
# 8.1 seconds of data processed
# Last batch took: 0.21 seconds
# 8.2 seconds of data processed
# Last batch took: 0.27 seconds
# 8.3 seconds of data processed
# Last batch took: 0.23 seconds
# 8.4 seconds of data processed
# Last batch took: 0.22 seconds
# 8.5 seconds of data processed
# Last batch took: 0.34 seconds
# 8.6 seconds of data processed
# Last batch took: 0.26 seconds
# 8.7 seconds of data processed
# Last batch took: 0.32 seconds
# 8.8 seconds of data processed
# Last batch took: 0.21 seconds
# 8.9 seconds of data processed
# Last batch took: 0.26 seconds
# 9.0 seconds of data processed
# Last batch took: 0.25 seconds
# 9.1 seconds of data processed
# Last batch took: 0.27 seconds
# 9.2 seconds of data processed
# Last batch took: 0.22 seconds
# 9.3 seconds of data processed
# Last batch took: 0.23 seconds
# 9.4 seconds of data processed
# Last batch took: 0.29 seconds
# 9.5 seconds of data processed
# Last batch took: 0.22 seconds
# 9.6 seconds of data processed
# Last batch took: 0.25 seconds
# 9.7 seconds of data processed
# Last batch took: 0.22 seconds
# 9.8 seconds of data processed
# Last batch took: 0.23 seconds
# 9.9 seconds of data processed
# Last batch took: 0.28 seconds
# 10.0 seconds of data processed
# Last batch took: 0.2 seconds
# 10.1 seconds of data processed
# Last batch took: 0.23 seconds
# 10.2 seconds of data processed
# Last batch took: 0.26 seconds
# 10.3 seconds of data processed
# Last batch took: 0.24 seconds
# 10.4 seconds of data processed
# Last batch took: 0.18 seconds
# 10.5 seconds of data processed
# Last batch took: 0.2 seconds
# 10.6 seconds of data processed
# Last batch took: 0.21 seconds
# 10.7 seconds of data processed
# Last batch took: 0.19 seconds
# 10.8 seconds of data processed
# Last batch took: 0.23 seconds
# 10.9 seconds of data processed
# Last batch took: 0.24 seconds
# 11.0 seconds of data processed
# Last batch took: 0.19 seconds
# 11.1 seconds of data processed
# Last batch took: 0.26 seconds
# 11.2 seconds of data processed
# Last batch took: 0.28 seconds
# 11.3 seconds of data processed
# Last batch took: 0.26 seconds
# 11.4 seconds of data processed
# Last batch took: 0.31 seconds
# 11.5 seconds of data processed
# Last batch took: 0.3 seconds
# 11.6 seconds of data processed
# Last batch took: 0.25 seconds
# 11.7 seconds of data processed
# Last batch took: 0.3 seconds
# 11.8 seconds of data processed
# Last batch took: 0.33 seconds
# 11.9 seconds of data processed
# Last batch took: 0.28 seconds
# 12.0 seconds of data processed
# Last batch took: 0.22 seconds
# 12.1 seconds of data processed
# Last batch took: 0.32 seconds
# 12.2 seconds of data processed
# Last batch took: 0.23 seconds
# 12.3 seconds of data processed
# Last batch took: 0.31 seconds
# 12.4 seconds of data processed
# Last batch took: 0.29 seconds
# 12.5 seconds of data processed
# Last batch took: 0.27 seconds
# 12.6 seconds of data processed
# Last batch took: 0.33 seconds
# 12.7 seconds of data processed
# Last batch took: 0.28 seconds
# 12.8 seconds of data processed
# Last batch took: 0.28 seconds
# 12.9 seconds of data processed
# Last batch took: 0.28 seconds
# 13.0 seconds of data processed
# Last batch took: 0.24 seconds
# 13.1 seconds of data processed
# Last batch took: 0.24 seconds
# 13.2 seconds of data processed
# Last batch took: 0.24 seconds
# 13.3 seconds of data processed
# Last batch took: 0.26 seconds
# 13.4 seconds of data processed
# Last batch took: 0.25 seconds
# 13.5 seconds of data processed
# Last batch took: 0.3 seconds
# 13.6 seconds of data processed
# Last batch took: 0.33 seconds
# 13.7 seconds of data processed
# Last batch took: 0.24 seconds
# 13.8 seconds of data processed
# Last batch took: 0.27 seconds
# 13.9 seconds of data processed
# Last batch took: 0.27 seconds
# 14.0 seconds of data processed
# Last batch took: 0.2 seconds
# 14.1 seconds of data processed
# Last batch took: 0.28 seconds
# 14.2 seconds of data processed
# Last batch took: 0.19 seconds
# 14.3 seconds of data processed
# Last batch took: 0.2 seconds
# 14.4 seconds of data processed
# Last batch took: 0.24 seconds
# 14.5 seconds of data processed
# Last batch took: 0.44 seconds
# 14.6 seconds of data processed
# Last batch took: 0.22 seconds
# 14.7 seconds of data processed
# Last batch took: 0.3 seconds
# 14.8 seconds of data processed
# Last batch took: 0.25 seconds
# 14.9 seconds of data processed
# Last batch took: 0.23 seconds
# 15.0 seconds of data processed
# Last batch took: 0.27 seconds
# 15.1 seconds of data processed
# Last batch took: 0.27 seconds
# 15.2 seconds of data processed
# Last batch took: 0.24 seconds
# 15.3 seconds of data processed
# Last batch took: 0.26 seconds
# 15.4 seconds of data processed
# Last batch took: 0.31 seconds
# 15.5 seconds of data processed
# Last batch took: 0.24 seconds
# 15.6 seconds of data processed
# Last batch took: 0.25 seconds
# 15.7 seconds of data processed
# Last batch took: 0.27 seconds
# 15.8 seconds of data processed
# Last batch took: 0.27 seconds
# 15.9 seconds of data processed
# Last batch took: 0.38 seconds
# 16.0 seconds of data processed
# Last batch took: 0.29 seconds
# 16.1 seconds of data processed
# Last batch took: 0.27 seconds
# 16.2 seconds of data processed
# Last batch took: 0.25 seconds
# 16.3 seconds of data processed
# Last batch took: 0.25 seconds
# 16.4 seconds of data processed
# Last batch took: 0.28 seconds
# 16.5 seconds of data processed
# Last batch took: 0.2 seconds
# 16.6 seconds of data processed
# Last batch took: 0.27 seconds
# 16.7 seconds of data processed
# Last batch took: 0.25 seconds
# 16.8 seconds of data processed
# Last batch took: 0.36 seconds
# 16.9 seconds of data processed
# Last batch took: 0.26 seconds
# 17.0 seconds of data processed
# Last batch took: 0.25 seconds
# 17.1 seconds of data processed
# Last batch took: 0.29 seconds
# 17.2 seconds of data processed
# Last batch took: 0.31 seconds
# 17.3 seconds of data processed
# Last batch took: 0.3 seconds
# 17.4 seconds of data processed
# Last batch took: 0.23 seconds
# 17.5 seconds of data processed
# Last batch took: 0.33 seconds
# 17.6 seconds of data processed
# Last batch took: 0.27 seconds
# 17.7 seconds of data processed
# Last batch took: 0.26 seconds
# 17.8 seconds of data processed
# Last batch took: 0.33 seconds
# 17.9 seconds of data processed
# Last batch took: 0.27 seconds
# 18.0 seconds of data processed
# Last batch took: 0.34 seconds
# 18.1 seconds of data processed
# Last batch took: 0.28 seconds
# 18.2 seconds of data processed
# Last batch took: 0.32 seconds
# 18.3 seconds of data processed
# Last batch took: 0.22 seconds
# 18.4 seconds of data processed
# Last batch took: 0.23 seconds
# 18.5 seconds of data processed
# Last batch took: 0.26 seconds
# 18.6 seconds of data processed
# Last batch took: 0.25 seconds
# 18.7 seconds of data processed
# Last batch took: 0.3 seconds
# 18.8 seconds of data processed
# Last batch took: 0.23 seconds
# 18.9 seconds of data processed
# Last batch took: 0.34 seconds
# 19.0 seconds of data processed
# Last batch took: 0.24 seconds
# 19.1 seconds of data processed
# Last batch took: 0.26 seconds
# 19.2 seconds of data processed
# Last batch took: 0.3 seconds
# 19.3 seconds of data processed
# Last batch took: 0.24 seconds
# 19.4 seconds of data processed
# Last batch took: 0.24 seconds
# 19.5 seconds of data processed
# Last batch took: 0.25 seconds
# 19.6 seconds of data processed
# Last batch took: 0.23 seconds
# 19.7 seconds of data processed
# Last batch took: 0.28 seconds
# 19.8 seconds of data processed
# Last batch took: 0.24 seconds
# 19.9 seconds of data processed
# Last batch took: 0.25 seconds
# 20.0 seconds of data processed
# Last batch took: 0.48 seconds
# 20.1 seconds of data processed
# Last batch took: 0.25 seconds
# 20.2 seconds of data processed
# Last batch took: 0.25 seconds
# 20.3 seconds of data processed
# Last batch took: 0.21 seconds
# 20.4 seconds of data processed
# Last batch took: 0.39 seconds
# 20.5 seconds of data processed
# Last batch took: 0.25 seconds
# 20.6 seconds of data processed
# Last batch took: 0.24 seconds
# 20.7 seconds of data processed
# Last batch took: 0.23 seconds
# 20.8 seconds of data processed
# Last batch took: 0.66 seconds
# 20.9 seconds of data processed
# Last batch took: 0.3 seconds
# 21.0 seconds of data processed
# Last batch took: 0.46 seconds
# 21.1 seconds of data processed
# Last batch took: 0.27 seconds
# 21.2 seconds of data processed
# Last batch took: 0.4 seconds
# 21.3 seconds of data processed
# Last batch took: 0.25 seconds
# 21.4 seconds of data processed
# Last batch took: 0.24 seconds
# 21.5 seconds of data processed
# Last batch took: 0.29 seconds
# 21.6 seconds of data processed
# Last batch took: 0.27 seconds
# 21.7 seconds of data processed
# Last batch took: 0.24 seconds
# 21.8 seconds of data processed
# Last batch took: 0.39 seconds
# 21.9 seconds of data processed
# Last batch took: 0.29 seconds
# 22.0 seconds of data processed
# Last batch took: 0.38 seconds
# 22.1 seconds of data processed
# Last batch took: 0.3 seconds
# 22.2 seconds of data processed
# Last batch took: 0.25 seconds
# 22.3 seconds of data processed
# Last batch took: 0.3 seconds
# 22.4 seconds of data processed
# Last batch took: 0.3 seconds
# 22.5 seconds of data processed
# Last batch took: 0.24 seconds
# 22.6 seconds of data processed
# Last batch took: 0.36 seconds
# 22.7 seconds of data processed
# Last batch took: 0.31 seconds
# 22.8 seconds of data processed
# Last batch took: 0.25 seconds
# 22.9 seconds of data processed
# Last batch took: 0.29 seconds
# 23.0 seconds of data processed
# Last batch took: 0.22 seconds
# 23.1 seconds of data processed
# Last batch took: 0.22 seconds
# 23.2 seconds of data processed
# Last batch took: 0.2 seconds
# 23.3 seconds of data processed
# Last batch took: 0.29 seconds
# 23.4 seconds of data processed
# Last batch took: 0.25 seconds
# 23.5 seconds of data processed
# Last batch took: 0.19 seconds
# 23.6 seconds of data processed
# Last batch took: 0.23 seconds
# 23.7 seconds of data processed
# Last batch took: 0.19 seconds
# 23.8 seconds of data processed
# Last batch took: 0.21 seconds
# 23.9 seconds of data processed
# Last batch took: 0.26 seconds
# 24.0 seconds of data processed
# Last batch took: 0.22 seconds
# 24.1 seconds of data processed
# Last batch took: 0.34 seconds
# 24.2 seconds of data processed
# Last batch took: 0.32 seconds
# 24.3 seconds of data processed
# Last batch took: 0.32 seconds
# 24.4 seconds of data processed
# Last batch took: 0.32 seconds
# 24.5 seconds of data processed
# Last batch took: 0.43 seconds
# 24.6 seconds of data processed
# Last batch took: 0.35 seconds
# 24.7 seconds of data processed
# Last batch took: 0.32 seconds
# 24.8 seconds of data processed
# Last batch took: 0.25 seconds
# 24.9 seconds of data processed
# Last batch took: 0.34 seconds
# 25.0 seconds of data processed
# Last batch took: 0.32 seconds
# 25.1 seconds of data processed
# Last batch took: 0.31 seconds
# 25.2 seconds of data processed
# Last batch took: 0.45 seconds
# 25.3 seconds of data processed
# Last batch took: 0.55 seconds
# 25.4 seconds of data processed
# Last batch took: 0.29 seconds
# 25.5 seconds of data processed
# Last batch took: 0.28 seconds
# 25.6 seconds of data processed
# Last batch took: 0.25 seconds
# 25.7 seconds of data processed
# Last batch took: 0.23 seconds
# 25.8 seconds of data processed
# Last batch took: 0.21 seconds
# 25.9 seconds of data processed
# Last batch took: 0.28 seconds
# 26.0 seconds of data processed
# Last batch took: 0.22 seconds
# 26.1 seconds of data processed
# Last batch took: 0.26 seconds
# 26.2 seconds of data processed
# Last batch took: 0.2 seconds
# 26.3 seconds of data processed
# Last batch took: 0.24 seconds
# 26.4 seconds of data processed
# Last batch took: 0.3 seconds
# 26.5 seconds of data processed
# Last batch took: 0.24 seconds
# 26.6 seconds of data processed
# Last batch took: 0.26 seconds
# 26.7 seconds of data processed
# Last batch took: 0.26 seconds
# 26.8 seconds of data processed
# Last batch took: 0.22 seconds
# 26.9 seconds of data processed
# Last batch took: 0.28 seconds
# 27.0 seconds of data processed
# Last batch took: 0.36 seconds
# 27.1 seconds of data processed
# Last batch took: 0.3 seconds
# 27.2 seconds of data processed
# Last batch took: 0.27 seconds
# 27.3 seconds of data processed
# Last batch took: 0.23 seconds
# 27.4 seconds of data processed
# Last batch took: 0.25 seconds
# 27.5 seconds of data processed
# Last batch took: 0.27 seconds
# 27.6 seconds of data processed
# Last batch took: 0.31 seconds
# 27.7 seconds of data processed
# Last batch took: 0.23 seconds
# 27.8 seconds of data processed
# Last batch took: 0.37 seconds
# 27.9 seconds of data processed
# Last batch took: 0.37 seconds
# 28.0 seconds of data processed
# Last batch took: 0.32 seconds
# 28.1 seconds of data processed
# Last batch took: 0.22 seconds
# 28.2 seconds of data processed
# Last batch took: 0.24 seconds
# 28.3 seconds of data processed
# Last batch took: 0.24 seconds
# 28.4 seconds of data processed
# Last batch took: 0.25 seconds
# 28.5 seconds of data processed
# Last batch took: 0.24 seconds
# 28.6 seconds of data processed
# Last batch took: 0.26 seconds
# 28.7 seconds of data processed
# Last batch took: 0.3 seconds
# 28.8 seconds of data processed
# Last batch took: 0.29 seconds
# 28.9 seconds of data processed
# Last batch took: 0.35 seconds
# 29.0 seconds of data processed
# Last batch took: 0.23 seconds
# 29.1 seconds of data processed
# Last batch took: 0.78 seconds
# 29.2 seconds of data processed
# Last batch took: 0.29 seconds
# 29.3 seconds of data processed
# Last batch took: 0.32 seconds
# 29.4 seconds of data processed
# Last batch took: 0.34 seconds
# 29.5 seconds of data processed
# Last batch took: 0.33 seconds
# 29.6 seconds of data processed
# Last batch took: 0.33 seconds
# 29.7 seconds of data processed
# Last batch took: 0.36 seconds
# 29.8 seconds of data processed
# Last batch took: 0.31 seconds
# 29.9 seconds of data processed
# Last batch took: 0.3 seconds
# 30.0 seconds of data processed
# Last batch took: 0.49 seconds
# 30.1 seconds of data processed
# Last batch took: 0.42 seconds
# 30.2 seconds of data processed
# Last batch took: 0.3 seconds
# 30.3 seconds of data processed
# Last batch took: 0.34 seconds
# 30.4 seconds of data processed
# Last batch took: 0.38 seconds
# 30.5 seconds of data processed
# Last batch took: 0.28 seconds
# 30.6 seconds of data processed
# Last batch took: 0.27 seconds
# 30.7 seconds of data processed
# Last batch took: 0.2 seconds
# 30.8 seconds of data processed
# Last batch took: 0.28 seconds
# 30.9 seconds of data processed
# Last batch took: 0.3 seconds
# 31.0 seconds of data processed
# Last batch took: 0.26 seconds
# 31.1 seconds of data processed
# Last batch took: 0.29 seconds
# 31.2 seconds of data processed
# Last batch took: 0.28 seconds
# 31.3 seconds of data processed
# Last batch took: 0.29 seconds
# 31.4 seconds of data processed
# Last batch took: 0.29 seconds
# 31.5 seconds of data processed
# Last batch took: 0.25 seconds
# 31.6 seconds of data processed
# Last batch took: 0.34 seconds
# 31.7 seconds of data processed
# Last batch took: 0.27 seconds
# 31.8 seconds of data processed
# Last batch took: 0.19 seconds
# 31.9 seconds of data processed
# Last batch took: 0.26 seconds
# 32.0 seconds of data processed
# Last batch took: 0.31 seconds
# 32.1 seconds of data processed
# Last batch took: 0.3 seconds
# 32.2 seconds of data processed
# Last batch took: 0.28 seconds
# 32.3 seconds of data processed
# Last batch took: 0.31 seconds
# 32.4 seconds of data processed
# Last batch took: 0.34 seconds
# 32.5 seconds of data processed
# Last batch took: 0.36 seconds
# 32.6 seconds of data processed
# Last batch took: 0.29 seconds
# 32.7 seconds of data processed
# Last batch took: 0.36 seconds
# 32.8 seconds of data processed
# Last batch took: 0.39 seconds
# 32.9 seconds of data processed
# Last batch took: 0.29 seconds
# 33.0 seconds of data processed
# Last batch took: 0.23 seconds
# 33.1 seconds of data processed
# Last batch took: 0.21 seconds
# 33.2 seconds of data processed
# Last batch took: 0.28 seconds
# 33.3 seconds of data processed
# Last batch took: 0.24 seconds
# 33.4 seconds of data processed
# Last batch took: 0.29 seconds
# 33.5 seconds of data processed
# Last batch took: 0.27 seconds
# 33.6 seconds of data processed
# Last batch took: 0.27 seconds
# 33.7 seconds of data processed
# Last batch took: 0.31 seconds
# 33.8 seconds of data processed
# Last batch took: 0.26 seconds
# 33.9 seconds of data processed
# Last batch took: 0.24 seconds
# 34.0 seconds of data processed
# Last batch took: 0.3 seconds
# 34.1 seconds of data processed
# Last batch took: 0.26 seconds
# 34.2 seconds of data processed
# Last batch took: 0.3 seconds
# 34.3 seconds of data processed
# Last batch took: 0.26 seconds
# 34.4 seconds of data processed
# Last batch took: 0.26 seconds
# 34.5 seconds of data processed
# Last batch took: 0.25 seconds
# 34.6 seconds of data processed
# Last batch took: 0.26 seconds
# 34.7 seconds of data processed
# Last batch took: 0.25 seconds
# 34.8 seconds of data processed
# Last batch took: 0.25 seconds
# 34.9 seconds of data processed
# Last batch took: 0.33 seconds
# 35.0 seconds of data processed
# Last batch took: 0.33 seconds
# 35.1 seconds of data processed
# Last batch took: 0.23 seconds
# 35.2 seconds of data processed
# Last batch took: 0.22 seconds
# 35.3 seconds of data processed
# Last batch took: 0.3 seconds
# 35.4 seconds of data processed
# Last batch took: 0.3 seconds
# 35.5 seconds of data processed
# Last batch took: 0.32 seconds
# 35.6 seconds of data processed
# Last batch took: 0.27 seconds
# 35.7 seconds of data processed
# Last batch took: 0.51 seconds
# 35.8 seconds of data processed
# Last batch took: 0.3 seconds
# 35.9 seconds of data processed
# Last batch took: 0.29 seconds
# 36.0 seconds of data processed
# Last batch took: 0.27 seconds
# 36.1 seconds of data processed
# Last batch took: 0.34 seconds
# 36.2 seconds of data processed
# Last batch took: 0.32 seconds
# 36.3 seconds of data processed
# Last batch took: 0.44 seconds
# 36.4 seconds of data processed
# Last batch took: 0.29 seconds
# 36.5 seconds of data processed
# Last batch took: 0.29 seconds
# 36.6 seconds of data processed
# Last batch took: 0.39 seconds
# 36.7 seconds of data processed
# Last batch took: 0.29 seconds
# 36.8 seconds of data processed
# Last batch took: 0.28 seconds
# 36.9 seconds of data processed
# Last batch took: 0.31 seconds
# 37.0 seconds of data processed
# Last batch took: 0.32 seconds
# 37.1 seconds of data processed
# Last batch took: 0.35 seconds
# 37.2 seconds of data processed
# Last batch took: 0.28 seconds
# 37.3 seconds of data processed
# Last batch took: 0.24 seconds
# 37.4 seconds of data processed
# Last batch took: 0.25 seconds
# 37.5 seconds of data processed
# Last batch took: 0.26 seconds
# 37.6 seconds of data processed
# Last batch took: 0.28 seconds
# 37.7 seconds of data processed
# Last batch took: 0.25 seconds
# 37.8 seconds of data processed
# Last batch took: 0.28 seconds
# 37.9 seconds of data processed
# Last batch took: 0.38 seconds
# 38.0 seconds of data processed
# Last batch took: 0.34 seconds
# 38.1 seconds of data processed
# Last batch took: 0.27 seconds
# 38.2 seconds of data processed
# Last batch took: 0.28 seconds
# 38.3 seconds of data processed
# Last batch took: 0.38 seconds
# 38.4 seconds of data processed
# Last batch took: 0.29 seconds
# 38.5 seconds of data processed
# Last batch took: 0.26 seconds
# 38.6 seconds of data processed
# Last batch took: 0.24 seconds
# 38.7 seconds of data processed
# Last batch took: 0.21 seconds
# 38.8 seconds of data processed
# Last batch took: 0.26 seconds
# 38.9 seconds of data processed
# Last batch took: 0.25 seconds
# 39.0 seconds of data processed
# Last batch took: 0.33 seconds
# 39.1 seconds of data processed
# Last batch took: 0.28 seconds
# 39.2 seconds of data processed
# Last batch took: 0.27 seconds
# 39.3 seconds of data processed
# Last batch took: 0.24 seconds
# 39.4 seconds of data processed
# Last batch took: 0.23 seconds
# 39.5 seconds of data processed
# Last batch took: 0.29 seconds
# 39.6 seconds of data processed
# Last batch took: 0.31 seconds
# 39.7 seconds of data processed
# Last batch took: 0.27 seconds
# 39.8 seconds of data processed
# Last batch took: 0.28 seconds
# 39.9 seconds of data processed
# Last batch took: 0.24 seconds
# 40.0 seconds of data processed
# Last batch took: 0.24 seconds
# 40.1 seconds of data processed
# Last batch took: 0.26 seconds
# 40.2 seconds of data processed
# Last batch took: 0.51 seconds
# 40.3 seconds of data processed
# Last batch took: 0.3 seconds
# 40.4 seconds of data processed
# Last batch took: 0.31 seconds
# 40.5 seconds of data processed
# Last batch took: 0.24 seconds
# 40.6 seconds of data processed
# Last batch took: 0.26 seconds
# 40.7 seconds of data processed
# Last batch took: 0.24 seconds
# 40.8 seconds of data processed
# Last batch took: 0.26 seconds
# 40.9 seconds of data processed
# Last batch took: 0.38 seconds
# 41.0 seconds of data processed
# Last batch took: 0.29 seconds
# 41.1 seconds of data processed
# Last batch took: 0.35 seconds
# 41.2 seconds of data processed
# Last batch took: 0.28 seconds
# 41.3 seconds of data processed
# Last batch took: 0.33 seconds
# 41.4 seconds of data processed
# Last batch took: 0.31 seconds
# 41.5 seconds of data processed
# Last batch took: 0.27 seconds
# 41.6 seconds of data processed
# Last batch took: 0.28 seconds
# 41.7 seconds of data processed
# Last batch took: 0.22 seconds
# 41.8 seconds of data processed
# Last batch took: 0.24 seconds
# 41.9 seconds of data processed
# Last batch took: 0.25 seconds
# 42.0 seconds of data processed
# Last batch took: 0.27 seconds
# 42.1 seconds of data processed
# Last batch took: 0.23 seconds
# 42.2 seconds of data processed
# Last batch took: 0.26 seconds
# 42.3 seconds of data processed
# Last batch took: 0.26 seconds
# 42.4 seconds of data processed
# Last batch took: 0.25 seconds
# 42.5 seconds of data processed
# Last batch took: 0.29 seconds
# 42.6 seconds of data processed
# Last batch took: 0.33 seconds
# 42.7 seconds of data processed
# Last batch took: 0.29 seconds
# 42.8 seconds of data processed
# Last batch took: 0.3 seconds
# 42.9 seconds of data processed
# Last batch took: 0.31 seconds
# 43.0 seconds of data processed
# Last batch took: 0.39 seconds
# 43.1 seconds of data processed
# Last batch took: 0.51 seconds
# 43.2 seconds of data processed
# Last batch took: 0.35 seconds
# 43.3 seconds of data processed
# Last batch took: 0.3 seconds
# 43.4 seconds of data processed
# Last batch took: 0.34 seconds
# 43.5 seconds of data processed
# Last batch took: 0.36 seconds
# 43.6 seconds of data processed
# Last batch took: 0.35 seconds
# 43.7 seconds of data processed
# Last batch took: 0.33 seconds
# 43.8 seconds of data processed
# Last batch took: 0.25 seconds
# 43.9 seconds of data processed
# Last batch took: 0.31 seconds
# 44.0 seconds of data processed
# Last batch took: 0.26 seconds
# 44.1 seconds of data processed
# Last batch took: 0.29 seconds
# 44.2 seconds of data processed
# Last batch took: 0.38 seconds
# 44.3 seconds of data processed
# Last batch took: 0.39 seconds
# 44.4 seconds of data processed
# Last batch took: 0.26 seconds
# 44.5 seconds of data processed
# Last batch took: 0.33 seconds
# 44.6 seconds of data processed
# Last batch took: 0.33 seconds
# 44.7 seconds of data processed
# Last batch took: 0.38 seconds
# 44.8 seconds of data processed
# Last batch took: 0.28 seconds
# 44.9 seconds of data processed
# Last batch took: 0.24 seconds
# 45.0 seconds of data processed
# Last batch took: 0.28 seconds
# 45.1 seconds of data processed
# Last batch took: 0.57 seconds
# 45.2 seconds of data processed
# Last batch took: 0.27 seconds
# 45.3 seconds of data processed
# Last batch took: 0.36 seconds
# 45.4 seconds of data processed
# Last batch took: 0.35 seconds
# 45.5 seconds of data processed
# Last batch took: 0.32 seconds
# 45.6 seconds of data processed
# Last batch took: 0.35 seconds
# 45.7 seconds of data processed
# Last batch took: 0.29 seconds
# 45.8 seconds of data processed
# Last batch took: 0.29 seconds
# 45.9 seconds of data processed
# Last batch took: 0.24 seconds
# 46.0 seconds of data processed
# Last batch took: 0.34 seconds
# 46.1 seconds of data processed
# Last batch took: 0.29 seconds
# 46.2 seconds of data processed
# Last batch took: 0.3 seconds
# 46.3 seconds of data processed
# Last batch took: 0.26 seconds
# 46.4 seconds of data processed
# Last batch took: 0.34 seconds
# 46.5 seconds of data processed
# Last batch took: 0.25 seconds
# 46.6 seconds of data processed
# Last batch took: 0.31 seconds
# 46.7 seconds of data processed
# Last batch took: 0.25 seconds
# 46.8 seconds of data processed
# Last batch took: 0.49 seconds
# 46.9 seconds of data processed
# Last batch took: 0.29 seconds
# 47.0 seconds of data processed
# Last batch took: 0.27 seconds
# 47.1 seconds of data processed
# Last batch took: 0.26 seconds
# 47.2 seconds of data processed
# Last batch took: 0.51 seconds
# 47.3 seconds of data processed
# Last batch took: 0.33 seconds
# 47.4 seconds of data processed
# Last batch took: 0.33 seconds
# 47.5 seconds of data processed
# Last batch took: 0.26 seconds
# 47.6 seconds of data processed
# Last batch took: 0.3 seconds
# 47.7 seconds of data processed
# Last batch took: 0.29 seconds
# 47.8 seconds of data processed
# Last batch took: 0.24 seconds
# 47.9 seconds of data processed
# Last batch took: 0.38 seconds
# 48.0 seconds of data processed
# Last batch took: 0.31 seconds
# 48.1 seconds of data processed
# Last batch took: 0.3 seconds
# 48.2 seconds of data processed
# Last batch took: 0.3 seconds
# 48.3 seconds of data processed
# Last batch took: 0.3 seconds
# 48.4 seconds of data processed
# Last batch took: 0.3 seconds
# 48.5 seconds of data processed
# Last batch took: 0.24 seconds
# 48.6 seconds of data processed
# Last batch took: 0.31 seconds
# 48.7 seconds of data processed
# Last batch took: 0.27 seconds
# 48.8 seconds of data processed
# Last batch took: 0.26 seconds
# 48.9 seconds of data processed
# Last batch took: 0.29 seconds
# 49.0 seconds of data processed
# Last batch took: 0.3 seconds
# 49.1 seconds of data processed
# Last batch took: 0.33 seconds
# 49.2 seconds of data processed
# Last batch took: 0.27 seconds
# 49.3 seconds of data processed
# Last batch took: 0.31 seconds
# 49.4 seconds of data processed
# Last batch took: 0.3 seconds
# 49.5 seconds of data processed
# Last batch took: 0.37 seconds
# 49.6 seconds of data processed
# Last batch took: 0.36 seconds
# 49.7 seconds of data processed
# Last batch took: 0.33 seconds
# 49.8 seconds of data processed
# Last batch took: 0.29 seconds
# 49.9 seconds of data processed
# Last batch took: 0.34 seconds
# 50.0 seconds of data processed
# Last batch took: 0.49 seconds
# 50.1 seconds of data processed
# Last batch took: 0.28 seconds
# 50.2 seconds of data processed
# Last batch took: 0.38 seconds
# 50.3 seconds of data processed
# Last batch took: 0.28 seconds
# 50.4 seconds of data processed
# Last batch took: 0.28 seconds
# 50.5 seconds of data processed
# Last batch took: 0.28 seconds
# 50.6 seconds of data processed
# Last batch took: 0.32 seconds
# 50.7 seconds of data processed
# Last batch took: 0.3 seconds
# 50.8 seconds of data processed
# Last batch took: 0.3 seconds
# 50.9 seconds of data processed
# Last batch took: 0.35 seconds
# 51.0 seconds of data processed
# Last batch took: 0.28 seconds
# 51.1 seconds of data processed
# Last batch took: 0.28 seconds
# 51.2 seconds of data processed
# Last batch took: 0.31 seconds
# 51.3 seconds of data processed
# Last batch took: 0.3 seconds
# 51.4 seconds of data processed
# Last batch took: 0.29 seconds
# 51.5 seconds of data processed
# Last batch took: 0.3 seconds
# 51.6 seconds of data processed
# Last batch took: 0.32 seconds
# 51.7 seconds of data processed
# Last batch took: 0.36 seconds
# 51.8 seconds of data processed
# Last batch took: 0.25 seconds
# 51.9 seconds of data processed
# Last batch took: 0.26 seconds
# 52.0 seconds of data processed
# Last batch took: 0.25 seconds
# 52.1 seconds of data processed
# Last batch took: 0.31 seconds
# 52.2 seconds of data processed
# Last batch took: 0.31 seconds
# 52.3 seconds of data processed
# Last batch took: 0.32 seconds
# 52.4 seconds of data processed
# Last batch took: 0.27 seconds
# 52.5 seconds of data processed
# Last batch took: 0.3 seconds
# 52.6 seconds of data processed
# Last batch took: 0.29 seconds
# 52.7 seconds of data processed
# Last batch took: 0.29 seconds
# 52.8 seconds of data processed
# Last batch took: 0.27 seconds
# 52.9 seconds of data processed
# Last batch took: 0.29 seconds
# 53.0 seconds of data processed
# Last batch took: 0.3 seconds
# 53.1 seconds of data processed
# Last batch took: 0.35 seconds
# 53.2 seconds of data processed
# Last batch took: 0.32 seconds
# 53.3 seconds of data processed
# Last batch took: 0.28 seconds
# 53.4 seconds of data processed
# Last batch took: 0.34 seconds
# 53.5 seconds of data processed
# Last batch took: 0.25 seconds
# 53.6 seconds of data processed
# Last batch took: 0.28 seconds
# 53.7 seconds of data processed
# Last batch took: 0.3 seconds
# 53.8 seconds of data processed
# Last batch took: 0.33 seconds
# 53.9 seconds of data processed
# Last batch took: 0.45 seconds
# 54.0 seconds of data processed
# Last batch took: 0.39 seconds
# 54.1 seconds of data processed
# Last batch took: 0.3 seconds
# 54.2 seconds of data processed
# Last batch took: 0.31 seconds
# 54.3 seconds of data processed
# Last batch took: 0.32 seconds
# 54.4 seconds of data processed
# Last batch took: 0.39 seconds
# 54.5 seconds of data processed
# Last batch took: 0.32 seconds
# 54.6 seconds of data processed
# Last batch took: 0.33 seconds
# 54.7 seconds of data processed
# Last batch took: 0.35 seconds
# 54.8 seconds of data processed
# Last batch took: 0.33 seconds
# 54.9 seconds of data processed
# Last batch took: 0.34 seconds
# 55.0 seconds of data processed
# Last batch took: 0.39 seconds
# 55.1 seconds of data processed
# Last batch took: 0.38 seconds
# 55.2 seconds of data processed
# Last batch took: 0.36 seconds
# 55.3 seconds of data processed
# Last batch took: 0.4 seconds
# 55.4 seconds of data processed
# Last batch took: 0.47 seconds
# 55.5 seconds of data processed
# Last batch took: 0.4 seconds
# 55.6 seconds of data processed
# Last batch took: 0.31 seconds
# 55.7 seconds of data processed
# Last batch took: 0.3 seconds
# 55.8 seconds of data processed
# Last batch took: 0.36 seconds
# 55.9 seconds of data processed
# Last batch took: 0.34 seconds
# 56.0 seconds of data processed
# Last batch took: 0.33 seconds
# 56.1 seconds of data processed
# Last batch took: 0.32 seconds
# 56.2 seconds of data processed
# Last batch took: 0.29 seconds
# 56.3 seconds of data processed
# Last batch took: 0.28 seconds
# 56.4 seconds of data processed
# Last batch took: 0.4 seconds
# 56.5 seconds of data processed
# Last batch took: 0.29 seconds
# 56.6 seconds of data processed
# Last batch took: 0.36 seconds
# 56.7 seconds of data processed
# Last batch took: 0.33 seconds
# 56.8 seconds of data processed
# Last batch took: 0.33 seconds
# 56.9 seconds of data processed
# Last batch took: 0.29 seconds
# 57.0 seconds of data processed
# Last batch took: 0.33 seconds
# 57.1 seconds of data processed
# Last batch took: 0.33 seconds
# 57.2 seconds of data processed
# Last batch took: 0.33 seconds
# 57.3 seconds of data processed
# Last batch took: 0.38 seconds
# 57.4 seconds of data processed
# Last batch took: 0.35 seconds
# 57.5 seconds of data processed
# Last batch took: 0.3 seconds
# 57.6 seconds of data processed
# Last batch took: 0.27 seconds
# 57.7 seconds of data processed
# Last batch took: 0.26 seconds
# 57.8 seconds of data processed
# Last batch took: 0.26 seconds
# 57.9 seconds of data processed
# _SIDECAR.json saved to /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/sub-000_ses-right_task-force_run-0_SIDECAR.json
# FEATURES.csv saved to /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/sub-000_ses-right_task-force_run-0_FEATURES.csv
# settings.json saved to /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/sub-000_ses-right_task-force_run-0_SETTINGS.json
# nm_channels.csv saved to /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/sub-000_ses-right_task-force_run-0_nm_channels.csv

# %% [markdown]
# As soon as the command stream.run() above is executed, the feature estimation step is done and the results are saved in the BIDS format into the /py_neuromodulation/examples/data/derivatives/sub-testsub_ses-EphysMedOff_task-buttonpress_run-0/ directory.
#
# The features are in a file _FEATURES.csv
# The used channels are stored in nm_channels.csv
# The settings chosen are in _SETTINGS.json
# Additional information that is not part of settings nor channels is stored in _SIDECAR.json

# %% [markdown]
# ## Analysing results
#
# We can now analyse the results of the feature estimation using the Feature_Reader class. All features are estimated for each channel. For now, we plot results for only one ECoG channel.

# %%
# init analyzer
feature_reader = nm_analysis.Feature_Reader(
    feature_dir=PATH_OUT, feature_file=RUN_NAME
)

# plot for a single channel
ch_used = feature_reader.nm_channels.query(
    '(type=="ecog") and (used == 1)'
).iloc[3]["new_name"]

feature_used = (
    "stft" if feature_reader.settings["features"]["stft"] else "fft"
)

feature_reader.plot_target_averaged_channel(
    ch=ch_used,
    list_feature_keywords=[feature_used],
    epoch_len=4,   # Length of epoch in seconds
    threshold=0.5, # Threshold to be used for identifying events
)
# Out:
# Feature epoch average figure saved to: /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/MOV_aligned_features_ch_ECOG_RIGHT_3-avgref_fft.png

# %% [markdown]
# # Beta power was first found to be abnormally high in the STN of PD patients and decreases during both movement preparation and movement execution . After movement termination, STN beta power normally shows a significant rebound. Is that what we see here?
# # Are those artifacts in the beggining of fft high/low beta and alpha and theta?

# %% [markdown]
# # Check text below

# %% [markdown]
# In the first plot we see how the features change before, during and after movement. The time axis of the features is aligned to the target channel.
#
# The function plot_target_averaged_channel() receives a threshold as optional input, for the case where the target is continuous, for example, a rotation movement. In that case, we need to threshold it somehow to get an "event", in which respect we can plot the features. For our case, it simplifies the problem to different classes and for t=0 a different class onsets, as we can see in the second plot, showing the target plotted for all events where it crossed the threshold.
#
# The lighter plot is the individual movement trace, and the thicker one is the average.
#
# The plot is saved as a .png in the /py_neuromodulation/examples/data/derivatives/sub-testsub_ses-EphysMedOff_task-buttonpress_run-0/ directory.

# %% [markdown]
# #### Plotting features over time

# %%
feature_reader.feature_arr.T
# Out:
#                                                   0            1    \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity    1821.387615  1205.637774
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility       0.096606     0.115420
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity     4.764258     4.085364
# ECOG_RIGHT_1-avgref_RawHjorth_Activity    1284.411746  1124.278095
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility       0.086777     0.089590
# ...                                               ...          ...
# gridcortex_27_bursts_low gamma_in_burst      0.683831     0.683831
# gridcortex_28_bursts_low gamma_in_burst      1.000000     1.000000
# gridcortex_32_bursts_low gamma_in_burst      1.000000     1.000000
# time                                      1000.000000  1100.000000
# MOV_LEFT_CLEAN                               0.000000     0.000000
#
#                                                   2            3    \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     973.868804   873.892093
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility       0.122838     0.122369
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity     3.935478     4.174707
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     800.175154   709.642393
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility       0.103360     0.108172
# ...                                               ...          ...
# gridcortex_27_bursts_low gamma_in_burst      0.000000     0.000000
# gridcortex_28_bursts_low gamma_in_burst      0.000000     0.000000
# gridcortex_32_bursts_low gamma_in_burst      0.000000     0.000000
# time                                      1200.000000  1300.000000
# MOV_LEFT_CLEAN                               0.000000     0.000000
#
#                                                   4            5    \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     627.469555  1355.869008
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility       0.128480     0.082647
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity     4.480980     7.254116
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     632.605227   607.889702
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility       0.109792     0.111169
# ...                                               ...          ...
# gridcortex_27_bursts_low gamma_in_burst      0.683831     1.000000
# gridcortex_28_bursts_low gamma_in_burst      1.000000     1.000000
# gridcortex_32_bursts_low gamma_in_burst      1.000000     1.000000
# time                                      1400.000000  1500.000000
# MOV_LEFT_CLEAN                               0.000000     0.000000
#
#                                                   6             7    \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity    5570.379457  12461.433855
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility       0.039814      0.027729
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity    15.342732     21.656742
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     467.297631    800.892320
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility       0.121729      0.096983
# ...                                               ...           ...
# gridcortex_27_bursts_low gamma_in_burst      1.000000      1.000000
# gridcortex_28_bursts_low gamma_in_burst      1.000000      1.000000
# gridcortex_32_bursts_low gamma_in_burst      1.000000      1.000000
# time                                      1600.000000   1700.000000
# MOV_LEFT_CLEAN                               0.000000      0.000000
#
#                                                    8             9    ...  \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity    18972.894042  24151.253443  ...
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility        0.023076      0.020988  ...
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity     26.017147     29.188501  ...
# ECOG_RIGHT_1-avgref_RawHjorth_Activity      793.719494    763.912218  ...
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility        0.099391      0.103597  ...
# ...                                                ...           ...  ...
# gridcortex_27_bursts_low gamma_in_burst       1.000000      1.000000  ...
# gridcortex_28_bursts_low gamma_in_burst       1.000000      1.000000  ...
# gridcortex_32_bursts_low gamma_in_burst       1.000000      1.000000  ...
# time                                       1800.000000   1900.000000  ...
# MOV_LEFT_CLEAN                                0.000000      0.000000  ...
#
#                                                    560           561  \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     3032.820442   2897.330703
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility        0.082749      0.084842
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity      4.934193      4.741715
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     1544.817650   1578.554266
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility        0.098629      0.096697
# ...                                                ...           ...
# gridcortex_27_bursts_low gamma_in_burst       0.316169      0.316169
# gridcortex_28_bursts_low gamma_in_burst       0.000000      0.000000
# gridcortex_32_bursts_low gamma_in_burst       0.000000      0.000000
# time                                      57000.000000  57100.000000
# MOV_LEFT_CLEAN                                0.000000      0.000000
#
#                                                    562           563  \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     2792.828772   2927.851394
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility        0.081772      0.079006
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity      5.154773      5.431436
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     1295.271905   1127.494167
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility        0.099119      0.105189
# ...                                                ...           ...
# gridcortex_27_bursts_low gamma_in_burst       0.683831      0.000000
# gridcortex_28_bursts_low gamma_in_burst       1.000000      0.000000
# gridcortex_32_bursts_low gamma_in_burst       1.000000      0.000000
# time                                      57200.000000  57300.000000
# MOV_LEFT_CLEAN                                0.000000      0.000000
#
#                                                    564           565  \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     2980.964648   3451.074088
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility        0.074605      0.067477
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity      6.123445      6.913660
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     1126.051270   1153.483849
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility        0.101445      0.101315
# ...                                                ...           ...
# gridcortex_27_bursts_low gamma_in_burst       0.000000      0.000000
# gridcortex_28_bursts_low gamma_in_burst       0.000000      0.000000
# gridcortex_32_bursts_low gamma_in_burst       0.000000      0.000000
# time                                      57400.000000  57500.000000
# MOV_LEFT_CLEAN                                0.000000      0.000000
#
#                                                    566           567  \
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     3735.145974   4030.274051
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility        0.064018      0.059925
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity      7.570926      8.282472
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     1351.366283   1347.056279
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility        0.094277      0.093771
# ...                                                ...           ...
# gridcortex_27_bursts_low gamma_in_burst       0.000000      0.316169
# gridcortex_28_bursts_low gamma_in_burst       0.000000      0.000000
# gridcortex_32_bursts_low gamma_in_burst       0.000000      0.000000
# time                                      57600.000000  57700.000000
# MOV_LEFT_CLEAN                                0.000000      0.000000
#
#                                                    568           569
# ECOG_RIGHT_0-avgref_RawHjorth_Activity     3721.263896   3248.262596
# ECOG_RIGHT_0-avgref_RawHjorth_Mobility        0.059855      0.060261
# ECOG_RIGHT_0-avgref_RawHjorth_Complexity      8.683255      9.237236
# ECOG_RIGHT_1-avgref_RawHjorth_Activity     1184.103824    969.901522
# ECOG_RIGHT_1-avgref_RawHjorth_Mobility        0.097926      0.099609
# ...                                                ...           ...
# gridcortex_27_bursts_low gamma_in_burst       0.000000      0.000000
# gridcortex_28_bursts_low gamma_in_burst       0.000000      0.000000
# gridcortex_32_bursts_low gamma_in_burst       0.000000      0.000000
# time                                      57800.000000  57900.000000
# MOV_LEFT_CLEAN                                0.000000      0.000000
#
# [1696 rows x 570 columns]

# %% [markdown]
# Since the values for each feature are in very different scales, we make them comparable by z-scoring each feature separately. We use the `zscore` function from `nm_stats.py`.

# %%
# We arbitrarily decided to plot the features from the first ECoG channel
ch_name = 'ECOG_RIGHT_3-avgref'
# In order to make nice labels in the y axis we do:
feature_names = list(feature_reader.feature_arr.filter(regex=ch_name)[:].columns)
df_first_ecog_ch = feature_reader.feature_arr.filter(regex=ch_name)
zscored_df = df_first_ecog_ch.apply(nm_stats.zscore, axis = 0)

feature_col_name = [
    i[len(ch_name) + 1 :] for i in feature_names if ch_name in i
]

fig, axs = plt.subplots(2,1,gridspec_kw={'height_ratios': [3, 1]}, figsize = (30,28) )

# Here we remove the first data point from all features, because the normalization only starts in the second data point.

im = axs[0].imshow(zscored_df.T, aspect='auto', vmin = -2, vmax = 2)
axs[0].set_yticks(np.arange(0, len(feature_names), 1), feature_col_name)
x_labels_pos = np.linspace(0, len(feature_reader.feature_arr)-1, 9, dtype=int)
xlabels = list(np.linspace(feature_reader.feature_arr['time'].iloc[0], feature_reader.feature_arr['time'].iloc[-1], 9, dtype = int))
axs[0].set_xticks(x_labels_pos, xlabels)
axs[0].set_title("Estimated features over time for channel {}".format(ch_name))
cbar = fig.colorbar(im, ax=axs[0], location = 'top', aspect = 35)
axs[0].set_xlabel("Time [ms]")

axs[1].plot(feature_reader.feature_arr["MOV_LEFT_CLEAN"])
axs[1].set_xticks(x_labels_pos, xlabels)
axs[1].set_xlabel("Time [ms]")
axs[1].set_title("Target - MOV_LEFT_CLEAN");

# %% [markdown]
# # Should we make the movement plots binary?

# %% [markdown]
# ### Correlation matrix of many features
# It might also be useful to look at how features correlate with each other. Here, we can use the function ```plot_corr_matrix``` from ```nm_plots```.
# Since we have too many features, let's plot only the features from the ECoG channel ```'ECOG_L_1_SMC_AT```.

# %% [markdown]
# # Colorbar range from 0 to 1?

# %%
nm_plots.plot_corr_matrix(
        feature = feature_reader.feature_arr.filter(regex='ECOG_RIGHT_3'),
        ch_name= 'ECOG_RIGHT_3-avgref',
        OUT_PATH= PATH_OUT,
        feature_names=feature_reader.feature_arr.filter(regex='ECOG_RIGHT_3').columns,
        feature_file=feature_reader.feature_file,
        show_plot=True,
        figsize=(15,15),
)
# Out:
# Correlation matrix figure saved to /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/Features_corr_matr_ch_ECOG_RIGHT_3-avgref.png

# %% [markdown]
# ## Decoding
#
# The main focus of the py_neuromodulation pipeline is the feature estimation. Nevertheless, the user can also use the pipeline for Machine Learning decoding. It can be used for regression and classification problems, and also for unsupervised methods, such as PCA and CCA.
#
# Here we show an example using the XGBOOST Classifier. The labels used come from the target, in this case, the "SQUARED_ROTATION".
#
# The performance results are saved and plotted below. Again the figure is saved as a .png in the /py_neuromodulation/examples/data/derivatives/sub-testsub_ses-EphysMedOff_task-buttonpress_run-0/ directory.

# %%
model = xgboost.XGBClassifier(use_label_encoder=False)


feature_reader.decoder = nm_decode.Decoder(
    features=feature_reader.feature_arr,
    label=feature_reader.label,
    label_name=feature_reader.label_name,
    used_chs=feature_reader.used_chs,
    model=model,
    eval_method=metrics.balanced_accuracy_score,
    cv_method=model_selection.KFold(n_splits=3, shuffle=True),
    get_movement_detection_rate=True,
    min_consequent_count=2,
    TRAIN_VAL_SPLIT=False,
    RUN_BAY_OPT=False,
    use_nested_cv=False,
    sfreq=feature_reader.settings["sampling_rate_features_hz"],
)

performances = feature_reader.run_ML_model(
    estimate_channels=True,
    estimate_gridpoints=False,
    estimate_all_channels_combined=True,
    save_results=True,
)

df_per = feature_reader.get_dataframe_performances(performances)

nm_plots.plot_df_subjects(
    df_per, x_col="sub", y_col="performance_test", hue="ch_type",
    PATH_SAVE=os.path.join(PATH_OUT, RUN_NAME, RUN_NAME + "_decoding_performance.png")
)
# Out:
# model being saved to: /home/lauraflyra/Documents/BCCN/Lab_Rotation_DBS_Decoding/Code/py_neuromodulation/examples/data/derivatives/sub-000_ses-right_task-force_run-0/sub-000_ses-right_task-force_run-0_LM_ML_RES.p

# %% [markdown]
# ### References
#
# Holdgraf, C., Appelhoff, S., Bickel, S. et al. iEEG-BIDS, extending the Brain Imaging Data Structure specification to human intracranial electrophysiology. Sci Data 6, 102 (2019). https://doi.org/10.1038/s41597-019-0105-7
#
# Appelhoff, S., Sanderson, M., Brooks, T., Vliet, M., Quentin, R., Holdgraf, C., Chaumon, M., Mikulan, E., Tavabi, K., Höchenberger, R., Welke, D., Brunner, C., Rockhill, A., Larson, E., Gramfort, A., & Jas, M. (2019). MNE-BIDS: Organizing electrophysiological data into the BIDS format and facilitating their analysis. Journal of Open Source Software, 4:1896. DOI: 10.21105/joss.01896
#
# https://www.brainproducts.com/support-resources/brainvision-core-data-format-1-0/
